# %%
import numpy as np
from math import sqrt
import matplotlib.pyplot as plt
import warnings
from matplotlib import style
from collections import Counter

style.use('fivethirtyeight')
# the points are called features.  2D features.  
# Features that correspond to the class of k and features that correspond to class r
dataset = {'k': [[1,2], [2,3], [3,1]], 'r':[[6,5],[7,7],[8,6]]}
new_features = [5,7]


# ii is the same as using j
for i in dataset:
  for ii in dataset[i]:
    plt.scatter(ii[0], ii[1], s=100, color=i) # for ii in daataset[i]] for i in dataset]

# %%
for i in dataset:
  for j in dataset[i]:
    plt.scatter(j[0], j[1], s=100, color=i)

# %%
# One line version
[[plt.scatter(ii[0], ii[1], s=100, color=i) for ii in dataset[i]] for i in dataset]
# Out:
# [[<matplotlib.collections.PathCollection at 0x7ff106f6d2d0>,
#   <matplotlib.collections.PathCollection at 0x7ff106f6d590>,
#   <matplotlib.collections.PathCollection at 0x7ff106f6da10>],
#  [<matplotlib.collections.PathCollection at 0x7ff106f6de10>,
#   <matplotlib.collections.PathCollection at 0x7ff106efe250>,
#   <matplotlib.collections.PathCollection at 0x7ff106efe690>]]

# %%
# Pick Program up here
[[plt.scatter(ii[0], ii[1], s=100, color=i) for ii in dataset[i]] for i in dataset]

# Show the new_features to visualize what class it most likely belongs to.
plt.scatter(new_features[0], new_features[1], s=100)
plt.show()

# %%
def k_nearest_neighbors(data, predict, k=3):

  # length of a dictionary is equal to its number of keys
  if len(data) >= k:
    warnings.warn('K is set to a value less than total voting groups!')

  knnalgos
  return vote_result
